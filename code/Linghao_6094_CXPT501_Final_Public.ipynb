# %% [markdown]
# # **Description**

# %% [markdown]
# For the CXPT501 final project, you will explore a large dataset that we simulated and modified based on a clinical trial (PIONEER-HF, ClinicalTrials.gov Identifier: NCT02554890).
#
# In this study, researchers compared the effects of sacubitril/valsartan versus enalapril in stabilized acute heart failure patients with reduced ejection fraction.

# %% [markdown]
# ##*Information included in the dataset*:
#
# *Demographics*
# *   Age
# *   Sex
# *   Race
# *   Ethnicity
#
# *Baseline characteristics*
# *   Height (cm)
# *   Weight (kg)
# *   Smoking history
# *   Pre-treatment NT-proBNP (pg/mL)
# *   Pre-treatment BNP (pg/mL)
#
# *Disease characteristics*
# *   Prior use of ACEi/ARB
# *   Left ventricular ejection fraction (%)
# *   Chronic renal insufficiency
#
# *Intervention*
# *   Sacubitril/valsartan
# *   Enalapril
#
# *Efficacy outcome*
# *   Week 4 NT-proBNP (pg/mL)
# *   Week 8 NT-proBNP (pg/mL)
#
# *Safety outcome*
# *   Symptomatic hypotension
# *   Hyperkalemia
# *   Angioedema
# *   Death

# %% [markdown]
# # **Instructions**

# %% [markdown]
# ## **Data import (6 points)**

# %% [markdown]
# **Import the Python libraries you decide to use here, e.g. Pandas (2 points)**

# %%
import pandas as pd

# %% [markdown]
# **Download/load your individual dataset (.csv file) (2 points)**

# %% [markdown]
# We have prepared a dataset for each of you, labeled by name. Please download or directly import your corresponding data file from https://github.com/Mangul-Lab-USC/CXPT-501-Fall_23. Each dataset contains data for 1 million patients, one per row.
#
# For directly importing your file from GitHub to your Colab notebook, click on your assigned file then right-click the Download button. From there, a drop-down menu like below should appear. Select the option that copies the direct link address to your clipboard, then paste it into your notebook.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **The drop-down menu shown in Google Chrome.** If you use this web browser, click "Copy link address".

# %%
import pandas as pd

# Replace 'your_file.csv' with the path to your CSV file
file_path = 'https://raw.githubusercontent.com/Mangul-Lab-USC/CXPT-501-Fall_23/main/Linghao_Zou.csv'

# Read the CSV file into a Pandas DataFrame
df = pd.read_csv(file_path, error_bad_lines=False)
# Out:
# <ipython-input-36-abf59fd53322>:7: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(file_path, error_bad_lines=False)

# %% [markdown]
# **Display the dataset (2 points)**

# %%
# Display the DataFrame
df.head(10)
# Out:
#     Age     Sex              Race               Ethnicity  Height (cm)  \
# 0  78.0    Male         Caucasian  Not Hispanic or Latino        204.0
# 1  64.0  Female             Other  Not Hispanic or Latino        183.0
# 2  30.0  Female           Unknown      Hispanic or Latino        164.0
# 3  20.0  Female             Other  Not Hispanic or Latino        169.0
# 4  50.0    Male             Asian      Hispanic or Latino        187.0
# 5  72.0    Male             Asian  Not Hispanic or Latino        204.0
# 6  54.0    Male         Caucasian      Hispanic or Latino        181.0
# 7  72.0    Male  Pacific Islander  Not Hispanic or Latino        201.0
# 8  75.0    Male           Unknown  Not Hispanic or Latino        157.0
# 9  48.0  Female           Unknown  Not Hispanic or Latino        181.0
#
#    Weight (kg) Smoking history  Pre-treatment NT-proBNP (pg/mL)  \
# 0        109.0         current                         5276.806
# ...

# %% [markdown]
# ## **Data cleaning (16 points)**

# %% [markdown]
# **Please remove all rows that have any NaN value in them (2 points)**
#
# You can confirm that you've done this properly by using:
# ```
# DataFrame.isnull().sum()
# ```

# %%
df = df.dropna()

# %%
#confirm
df.isnull().sum()
# Out:
# Age                                       0
# Sex                                       0
# Race                                      0
# Ethnicity                                 0
# Height (cm)                               0
# Weight (kg)                               0
# Smoking history                           0
# Pre-treatment NT-proBNP (pg/mL)           0
# Week 4 NT-proBNP (pg/mL)                  0
# Week 8 NT-proBNP (pg/mL)                  0
# Pre-treatment BNP (pg/mL)                 0
# Prior use of ACEi/ARB                     0
# Left ventricular ejection fraction (%)    0
# Chronic renal insufficiency               0
# Group                                     0
# Symptomatic hypotension                   0
# Hyperkalemia                              0
# Death                                     0
# dtype: int64

# %% [markdown]
# **Based on the study's inclusion criteria, please filter out patients who don't meet the following criteria. Store the remaining patient data in a new DataFrame. (8 points)**
#
# *Inclusion criteria*
# *   age >= 18
# *   pre-treatment NT-proBNP >= 1600 pg/mL
# *   pre-treatment BNP >= 400 pg/mL
# *   left ventricular ejection fraction <= 40%
#
# You can confirm how many patient entries remain by using:
# ```
# len(DataFrame)
# ```

# %%
filtered_df=df[(df['Age']>=18)&(df['Pre-treatment NT-proBNP (pg/mL)']>=1600)&(df['Pre-treatment BNP (pg/mL)']>=400)&(df['Left ventricular ejection fraction (%)']<=40)]

# %%
filtered_df.head(4)
# Out:
#     Age     Sex       Race               Ethnicity  Height (cm)  Weight (kg)  \
# 0  78.0    Male  Caucasian  Not Hispanic or Latino        204.0        109.0
# 1  64.0  Female      Other  Not Hispanic or Latino        183.0        102.0
# 3  20.0  Female      Other  Not Hispanic or Latino        169.0         87.0
# 4  50.0    Male      Asian      Hispanic or Latino        187.0         49.0
#
#   Smoking history  Pre-treatment NT-proBNP (pg/mL)  Week 4 NT-proBNP (pg/mL)  \
# 0         current                         5276.806                  3941.774
# 1         current                         6171.412                  4610.045
# 3         current                         6028.951                  4503.626
# 4           never                         5552.794                  4147.937
#
#    Week 8 NT-proBNP (pg/mL)  Pre-treatment BNP (pg/mL) Prior use of ACEi/ARB  \
# 0                  2944.505                   1453.519                    No
# ...

# %%
len(filtered_df)
# Out:
# 888

# %% [markdown]
# **Add a "BMI (kg/m^2)" column to the dataframe by calculating body mass index based on weight and height provided** `BMI = weight(kg)/(height(m)**2)` **where** '`**`' **is  the exponent operator in Python. Be wary of units. (6 points)**

# %%
#Append a new BMI column to the filtered df (I have converted cm into m, divided by 100):
filtered_df['BMI (kg/m^2)']=filtered_df['Weight (kg)']/((filtered_df['Height (cm)']/100)**2)
filtered_df.tail(5)
# Out:
# <ipython-input-43-119253bec693>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df['BMI (kg/m^2)']=filtered_df['Weight (kg)']/((filtered_df['Height (cm)']/100)**2)
#       Age     Sex       Race               Ethnicity  Height (cm)  \
# 994  76.0  Female      Other  Not Hispanic or Latino        199.0
# 995  34.0  Female      Asian  Not Hispanic or Latino        160.0
# 997  20.0    Male      Asian  Not Hispanic or Latino        203.0
# 998  76.0    Male  Caucasian      Hispanic or Latino        169.0
# 999  50.0  Female      Asian      Hispanic or Latino        163.0
#
#      Weight (kg) Smoking history  Pre-treatment NT-proBNP (pg/mL)  \
# 994         74.0           never                         6425.075
# ...

# %%
#Sort the table by Age
new_df = filtered_df.sort_values(by='Age')
new_df.head(5)
# Out:
#       Age     Sex              Race               Ethnicity  Height (cm)  \
# 334  18.0  Female         Caucasian      Hispanic or Latino        161.0
# 958  18.0    Male         Caucasian  Not Hispanic or Latino        211.0
# 228  18.0  Female  Pacific Islander      Hispanic or Latino        152.0
# 120  18.0  Female           Unknown  Not Hispanic or Latino        199.0
# 795  18.0  Female         Caucasian  Not Hispanic or Latino        197.0
#
#      Weight (kg) Smoking history  Pre-treatment NT-proBNP (pg/mL)  \
# 334        111.0           never                         6064.400
# 958         62.0          former                         7065.900
# 228        118.0           never                         5591.452
# 120         91.0         current                         5475.684
# 795         91.0           never                         5961.758
#
#      Week 4 NT-proBNP (pg/mL)  Week 8 NT-proBNP (pg/mL)  \
# 334                  4530.107                  3383.990
# ...

# %% [markdown]
# ## **Data visualization (64 points)**

# %% [markdown]
# ###**Explore the baseline characteristics among sacubitril/valsartan and enalapril groups (14 points)**

# %% [markdown]
# **Categorical Data**
# *   Based on your judgement, use one or more of the most appropriate plot types to visualize some aspect of the categorical data. Intervention type must be distinguished by hue.
# *   Make the following aesthetic changes to your plot as you see fit to make the visualization better:
#
#     ・Use one of Seaborn's Plot-Styles
#
#     ・Use one of Seaborn's Plot-Contexts
#
#     ・Despine your plot
# * Save the plot you make in vector form (.pdf). Use `bbox_inches='tight'` when you do this.

# %%
#Check the unique items under "Group":
unique_categories = filtered_df['Group'].unique()
print(unique_categories)
# Out:
# ['Enalapril' 'Sacubitril-valsartan']

# %%
#Count the occurance
category_counts = df['Group'].value_counts()
print(category_counts)
# Out:
# Enalapril               499
# Sacubitril-valsartan    494
# Name: Group, dtype: int64

# %%
#Here is the draft for calculating all 4 levels as they have been asked below

import seaborn as sns
import matplotlib.pyplot as plt

# Set Seaborn style and context
sns.set(style="whitegrid")  # Choose a Seaborn plot style
sns.set_context("poster")  # Choose a Seaborn context

# Melt the DataFrame to long format for easier plotting
df_long = pd.melt(
    df,
    id_vars=['Group'],
    value_vars=[
        'Pre-treatment NT-proBNP (pg/mL)',
        'Week 4 NT-proBNP (pg/mL)',
        'Week 8 NT-proBNP (pg/mL)',
        'Pre-treatment BNP (pg/mL)',
    ],
    var_name='Week',
    value_name='NT-proBNP Level',
)

# Create a bar graph with hue for 'Group'
bar_plot = sns.catplot(
    x="Week",
    y="NT-proBNP Level",
    hue="Group",
    kind="bar",
    data=df_long,
    height=6,  # Adjust the height as needed
    aspect=2,  # Adjust the aspect ratio for better readability
)

# Despine the plot
sns.despine()

# Adjust axis labels and title
bar_plot.set_axis_labels("", "NT-proBNP Level (pg/mL)")
bar_plot.fig.suptitle("Effect of Intervention on NT-proBNP Levels", y=1.1)

# Rename x-axis labels to shorter forms
bar_plot.set(xticklabels=['Pre NT', 'Week 4', 'Week 8', 'Pre BNP'])

# Save the plot in vector form (.pdf)
bar_plot.savefig("bar_plot_weeks.pdf", format="pdf", bbox_inches="tight")

# Show the plot
plt.show()

# %%
#One more graph on ventricular ejection fraction b/w sex groups using violin graph:
import numpy as np
sns.set_context("poster")
sns.set(style="white")
color_new = ['red','blue']

ax = sns.violinplot(data=new_df,x='Sex', y='Left ventricular ejection fraction (%)', hue='Group',split='True',palette=color_new,zorder=3)
sns.despine()

ax.legend(loc='upper right', bbox_to_anchor=(1.4,0.8), title='Interventions', title_fontsize=10)
ax.set(xlabel = "Sex")

plt.title('LVEF% between interventions from two sex groups')

plt.savefig("violin.pdf", format="pdf", bbox_inches="tight")

plt.show()

# %% [markdown]
# ###**Explore the efficacy of sacubitril/valsartan and enalapril at 4 weeks and 8 weeks (36 points)**
# **Relational Data**
# *   Follow the steps below to visualize NT-proBNP concentrations over time with a relational-type plot.
# *   Make the following aesthetic changes to your plot as you see fit to make the visualization better:
#
#     ・Use one of Seaborn's Plot-Styles
#
#     ・Use one of Seaborn's Plot-Contexts
#
#     ・Despine your plot
# * Save the plot you make in vector form (.pdf). Use `bbox_inches='tight'` when you do this.

# %% [markdown]
# 1) Subset the cleaned and filtered DataFrame into three smaller DataFrames containing the following columns (8 points):
# *   Pre-treatment NT-proBNP & Intervention Group
# *   Week 4 NT-proBNP & Intervention Group
# *   Week 8 NT-proBNP & Intervention Group

# %%
pre_treatment = new_df[['Pre-treatment NT-proBNP (pg/mL)', 'Group']]
week_4 = new_df[['Week 4 NT-proBNP (pg/mL)', 'Group']]
week_8 = new_df[['Week 8 NT-proBNP (pg/mL)', 'Group']]

# %% [markdown]
# 2) Add a column to each of the three new DataFrames specifying each DataFrame's timepoint. The name of the column should be the same for each DataFrame (6 points).

# %%
pre_treatment['Timepoint'] = 'Pre-treatment'
week_4['Timepoint'] = 'Week 4'
week_8['Timepoint'] = 'Week 8'
# Out:
# <ipython-input-49-dfb6a12ab2ec>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pre_treatment['Timepoint'] = 'Pre-treatment'
# <ipython-input-49-dfb6a12ab2ec>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   week_4['Timepoint'] = 'Week 4'
# <ipython-input-49-dfb6a12ab2ec>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %% [markdown]
# 3) Merge all three of the new DataFrames via the most appropriate method. (6 points)

# %%
merged_df = pd.concat([pre_treatment, week_4, week_8])
merged_df.head(10)
# Out:
#      Pre-treatment NT-proBNP (pg/mL)                 Group      Timepoint  \
# 334                         6064.400             Enalapril  Pre-treatment
# 958                         7065.900  Sacubitril-valsartan  Pre-treatment
# 228                         5591.452             Enalapril  Pre-treatment
# 120                         5475.684             Enalapril  Pre-treatment
# 795                         5961.758  Sacubitril-valsartan  Pre-treatment
# 991                         7383.341  Sacubitril-valsartan  Pre-treatment
# 615                         5907.193  Sacubitril-valsartan  Pre-treatment
# 879                         6565.743  Sacubitril-valsartan  Pre-treatment
# 629                         6744.250  Sacubitril-valsartan  Pre-treatment
# 834                         6536.928  Sacubitril-valsartan  Pre-treatment
#
#      Week 4 NT-proBNP (pg/mL)  Week 8 NT-proBNP (pg/mL)
# 334                       NaN                       NaN
# ...

# %%
#Re-arrange and sort the whole df
merged_df.index.name = 'Patient ID'

sorted_df = merged_df[['Group'] + [col for col in merged_df.columns if col != 'Group']].sort_index()

sorted_df.head(12)
# Out:
#                 Group  Pre-treatment NT-proBNP (pg/mL)      Timepoint  \
# Patient ID
# 0           Enalapril                              NaN         Week 4
# 0           Enalapril                              NaN         Week 8
# 0           Enalapril                         5276.806  Pre-treatment
# 1           Enalapril                              NaN         Week 4
# 1           Enalapril                              NaN         Week 8
# 1           Enalapril                         6171.412  Pre-treatment
# 3           Enalapril                         6028.951  Pre-treatment
# 3           Enalapril                              NaN         Week 8
# 3           Enalapril                              NaN         Week 4
# 4           Enalapril                              NaN         Week 4
# 4           Enalapril                         5552.794  Pre-treatment
# 4           Enalapril                              NaN         Week 8
#
# ...

# %% [markdown]
# 4 ) Fill in any NaNs in the merged DataFrame with the integer value 0. (2 points)

# %%
sorted_df.fillna(0)
# Out:
#                            Group  Pre-treatment NT-proBNP (pg/mL)  \
# Patient ID
# 0                      Enalapril                            0.000
# 0                      Enalapril                            0.000
# 0                      Enalapril                         5276.806
# 1                      Enalapril                            0.000
# 1                      Enalapril                            0.000
# ...                          ...                              ...
# 998         Sacubitril-valsartan                            0.000
# 998         Sacubitril-valsartan                         5365.810
# 999         Sacubitril-valsartan                            0.000
# 999         Sacubitril-valsartan                         5864.040
# 999         Sacubitril-valsartan                            0.000
#
#                 Timepoint  Week 4 NT-proBNP (pg/mL)  Week 8 NT-proBNP (pg/mL)
# Patient ID
# ...

# %% [markdown]
# 5) Combine all the columns containing NT-proBNP concentration data into a new, single column. (6 points)

# %%
sorted_df['NT-proBNP'] = sorted_df[['Pre-treatment NT-proBNP (pg/mL)', 'Week 4 NT-proBNP (pg/mL)', 'Week 8 NT-proBNP (pg/mL)']].sum(axis=1)
sorted_df.head(3)
# Out:
#                 Group  Pre-treatment NT-proBNP (pg/mL)      Timepoint  \
# Patient ID
# 0           Enalapril                              NaN         Week 4
# 0           Enalapril                              NaN         Week 8
# 0           Enalapril                         5276.806  Pre-treatment
#
#             Week 4 NT-proBNP (pg/mL)  Week 8 NT-proBNP (pg/mL)  NT-proBNP
# Patient ID
# 0                           3941.774                       NaN   3941.774
# 0                                NaN                  2944.505   2944.505
# 0                                NaN                       NaN   5276.806

# %%
#I also put Timepoint to the front, now the final df looks clean
final_df = sorted_df[['Timepoint'] + [col for col in sorted_df.columns if col != 'Timepoint']]
final_df.head(5)
# Out:
#                 Timepoint      Group  Pre-treatment NT-proBNP (pg/mL)  \
# Patient ID
# 0                  Week 4  Enalapril                              NaN
# 0                  Week 8  Enalapril                              NaN
# 0           Pre-treatment  Enalapril                         5276.806
# 1                  Week 4  Enalapril                              NaN
# 1                  Week 8  Enalapril                              NaN
#
#             Week 4 NT-proBNP (pg/mL)  Week 8 NT-proBNP (pg/mL)  NT-proBNP
# Patient ID
# 0                           3941.774                       NaN   3941.774
# 0                                NaN                  2944.505   2944.505
# 0                                NaN                       NaN   5276.806
# 1                           4610.045                       NaN   4610.045
# 1                                NaN                  3443.704   3443.704

# %%
#somehow need to fill nan again
final_df.fillna(0)
# Out:
#                 Timepoint                 Group  \
# Patient ID
# 0                  Week 4             Enalapril
# 0                  Week 8             Enalapril
# 0           Pre-treatment             Enalapril
# 1                  Week 4             Enalapril
# 1                  Week 8             Enalapril
# ...                   ...                   ...
# 998                Week 8  Sacubitril-valsartan
# 998         Pre-treatment  Sacubitril-valsartan
# 999                Week 4  Sacubitril-valsartan
# 999         Pre-treatment  Sacubitril-valsartan
# 999                Week 8  Sacubitril-valsartan
#
#             Pre-treatment NT-proBNP (pg/mL)  Week 4 NT-proBNP (pg/mL)  \
# Patient ID
# 0                                     0.000                  3941.774
# 0                                     0.000                     0.000
# 0                                  5276.806                     0.000
# 1                                     0.000                  4610.045
# ...

# %% [markdown]
# 6) Use a line plot to graph NT-proBNP concentration over time, with Intervention Group seperated by hue. (8 points)
#
# The arguements you pass to lineplot() should include:
# *   `ci='sd'`
# *   `err_style='bars'`
# *   `marker="o"`

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.set(style="whitegrid")
sns.set_context("paper")

# Plotting NT-proBNP concentration over time
plt.figure(figsize=(10, 6))
sns.lineplot(data=final_df, x='Timepoint', y='NT-proBNP', hue='Group', ci='sd', err_style='bars', marker='o')

# Adding labels and title
plt.xlabel('Timepoint')
plt.ylabel('NT-proBNP Concentration')
plt.title('NT-proBNP Concentration Over Time by Intervention Group')

#Adjust legend
plt.legend(loc='upper left')

# Remove the spines
sns.despine()

#Save the plot in vector form (.pdf)
plt.savefig('NT-proBMP_over_time.pdf', format='pdf', bbox_inches='tight')


# Display the plot
plt.show()
# Out:
# <ipython-input-56-e2f530aa90e4>:9: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar='sd'` for the same effect.
#
#   sns.lineplot(data=final_df, x='Timepoint', y='NT-proBNP', hue='Group', ci='sd', err_style='bars', marker='o')

# %% [markdown]
# ###**Explore the efficacy of sacubitril/valsartan and enalapril for a  demographic (8 points)**

# %% [markdown]
# **Matrix Data**
# *   Follow the steps below to produce a heatmap to visualize NT-proBNP concentration at Week 8 for some demographic of your choice. Intervention type must be an axis of the matrix data.
# *   Make the following aesthetic changes to your plot as you see fit to make the visualization better:
#
#     ・Use one of Seaborn's Plot-Contexts
#
# * Save the plot you make in vector form (.pdf). Use `bbox_inches='tight'` when you do this.

# %% [markdown]
# 1) Convert your categorical data into matrix data. (4 points)

# %%
df.head()
# Out:
#     Age     Sex       Race               Ethnicity  Height (cm)  Weight (kg)  \
# 0  78.0    Male  Caucasian  Not Hispanic or Latino        204.0        109.0
# 1  64.0  Female      Other  Not Hispanic or Latino        183.0        102.0
# 2  30.0  Female    Unknown      Hispanic or Latino        164.0        119.0
# 3  20.0  Female      Other  Not Hispanic or Latino        169.0         87.0
# 4  50.0    Male      Asian      Hispanic or Latino        187.0         49.0
#
#   Smoking history  Pre-treatment NT-proBNP (pg/mL)  Week 4 NT-proBNP (pg/mL)  \
# 0         current                         5276.806                  3941.774
# 1         current                         6171.412                  4610.045
# 2          former                         7320.380                  5468.324
# 3         current                         6028.951                  4503.626
# 4           never                         5552.794                  4147.937
#
# ...

# %%
print(df.columns)
# Out:
# Index(['Age', 'Sex', 'Race', 'Ethnicity', 'Height (cm)', 'Weight (kg)',
#        'Smoking history', 'Pre-treatment NT-proBNP (pg/mL)',
#        'Week 4 NT-proBNP (pg/mL)', 'Week 8 NT-proBNP (pg/mL)',
#        'Pre-treatment BNP (pg/mL)', 'Prior use of ACEi/ARB',
#        'Left ventricular ejection fraction (%)', 'Chronic renal insufficiency',
#        'Group', 'Symptomatic hypotension', 'Hyperkalemia', 'Death'],
#       dtype='object')

# %%
# Subset the DataFrame
subset_df = df[['Ethnicity', 'Group', 'Week 8 NT-proBNP (pg/mL)']]

# Pivot the DataFrame to create a matrix
matrix_data_ethinity = subset_df.pivot_table(index='Ethnicity', columns='Group', values='Week 8 NT-proBNP (pg/mL)', aggfunc='mean')

matrix_data_ethinity
# Out:
# Group                     Enalapril  Sacubitril-valsartan
# Ethnicity
# Hispanic or Latino      3421.957075           1729.271915
# Not Hispanic or Latino  3479.101455           1740.613774

# %%
# Subset the DataFrame
subset_df_race = df[['Race', 'Group', 'Week 8 NT-proBNP (pg/mL)']]

# Pivot the DataFrame to create a matrix
matrix_data_race = subset_df_race.pivot_table(index='Race', columns='Group', values='Week 8 NT-proBNP (pg/mL)', aggfunc='mean')

matrix_data_race
# Out:
# Group               Enalapril  Sacubitril-valsartan
# Race
# Asian             3380.745133           1748.417235
# Black             3505.610495           1717.105571
# Caucasian         3438.119364           1742.545356
# Native American   3416.864590           1704.265935
# Other             3418.706930           1752.768186
# Pacific Islander  3494.894375           1751.788661
# Unknown           3481.626238           1724.199382

# %% [markdown]
# 2) Plot a heatmap from your matrix data. It is okay if it does not look very complex. (4 points)

# %%
# Plot the heatmap for ethinity
plt.figure(figsize=(10, 6))
sns.heatmap(matrix_data_ethinity, cmap='coolwarm', annot=True, fmt=".1f", linewidths=.5)

# Set the title and labels
plt.title('NT-proBNP Concentration at Week 8 by Ethnicity')
plt.xlabel('Intervention Group',color='red')
plt.ylabel('Ethnicity',color='green')

# Save the plot as a PDF
plt.savefig('heatmap_ethnity.pdf', bbox_inches='tight')

# Show the plot
plt.show()

# %%
# Plot the heatmap for race
plt.figure(figsize=(10, 6))
sns.heatmap(matrix_data_race, cmap='coolwarm', annot=True, fmt=".1f", linewidths=.5)

# Set the title and labels
plt.title('NT-proBNP Concentration at Week 8 by Race')
plt.xlabel('Intervention Group',color='cyan')
plt.ylabel('Ethnicity',color='purple')

# Save the plot as a PDF
plt.savefig('heatmap_race.pdf', bbox_inches='tight')

# Show the plot
plt.show()

# %% [markdown]
# ## **Statistical analysis (20 points)**

# %% [markdown]
# **Explore the safety of sacubitril/valsartan and enalapril in this stabilized acute heart failure patient population**

# %% [markdown]
# Please provide the following statistical measures for various characteristics, including BMI, and group the results by the intervention type (sacubitril/valsartan and enalapril):
#
# **For Sacubitril/Valsartan Intervention:**
#
# Mean and standard deviation (std) for each characteristic, including BMI.
# Median for each characteristic, including BMI.
#
# **For Enalapril Intervention:**
#
# Mean and standard deviation (std) for each characteristic, including BMI.
# Median for each characteristic, including BMI.  (4 points)

# %%
#Recall the df
new_df.head()
# Out:
#       Age     Sex              Race               Ethnicity  Height (cm)  \
# 334  18.0  Female         Caucasian      Hispanic or Latino        161.0
# 958  18.0    Male         Caucasian  Not Hispanic or Latino        211.0
# 228  18.0  Female  Pacific Islander      Hispanic or Latino        152.0
# 120  18.0  Female           Unknown  Not Hispanic or Latino        199.0
# 795  18.0  Female         Caucasian  Not Hispanic or Latino        197.0
#
#      Weight (kg) Smoking history  Pre-treatment NT-proBNP (pg/mL)  \
# 334        111.0           never                         6064.400
# 958         62.0          former                         7065.900
# 228        118.0           never                         5591.452
# 120         91.0         current                         5475.684
# 795         91.0           never                         5961.758
#
#      Week 4 NT-proBNP (pg/mL)  Week 8 NT-proBNP (pg/mL)  \
# 334                  4530.107                  3383.990
# ...

# %%
# For Sacubitril/Valsartan Intervention(group sv):
df_sv = new_df.loc[new_df['Group'] == 'Sacubitril-valsartan']

age_mean = df_sv['Age'].mean()
age_median = df_sv['Age'].median()
age_sd = df_sv['Age'].std()
print('The mean of the age(S/V group) is:', age_mean, 'The median of the age(sv group) is:', age_median, 'The sd of the age(S/V group) is:', age_sd)

height_mean = df_sv['Height (cm)'].mean()
height_median = df_sv['Height (cm)'].median()
height_sd = df_sv['Height (cm)'].std()
print('The mean of the height(S/V group) is:', height_mean, 'The median of the height(sv group) is:', height_median, 'The sd of the height(S/V group) is:', height_sd)

weight_mean = df_sv['Weight (kg)'].mean()
weight_median = df_sv['Weight (kg)'].median()
weight_sd = df_sv['Weight (kg)'].std()
print('The mean of the weight(S/V group) is:', weight_mean, 'The median of the weight(sv group) is:', weight_median, 'The sd of the weight(S/V group) is:', weight_sd)

BMI_mean = df_sv['BMI (kg/m^2)'].mean()
BMI_median = df_sv['BMI (kg/m^2)'].median()
BMI_sd = df_sv['BMI (kg/m^2)'].std()
# Out:
# The mean of the age(S/V group) is: 47.04719101123595 The median of the age(sv group) is: 45.0 The sd of the age(S/V group) is: 17.94611610650135
# The mean of the height(S/V group) is: 180.99550561797753 The median of the height(sv group) is: 180.0 The sd of the height(S/V group) is: 17.8779641284084
# The mean of the weight(S/V group) is: 79.75955056179775 The median of the weight(sv group) is: 81.0 The sd of the weight(S/V group) is: 23.395506224684734

# %%
# For Enalapril (e group):
df_e = new_df.loc[new_df['Group'] == 'Enalapril']

age_mean = df_e['Age'].mean()
age_median = df_e['Age'].median()
age_sd = df_e['Age'].std()
print('The mean of the age(e group) is:', age_mean, 'The median of the age(e group) is:', age_median, 'The sd of the age(e group) is:', age_sd)

height_mean = df_e['Height (cm)'].mean()
height_median = df_e['Height (cm)'].median()
height_sd = df_e['Height (cm)'].std()
print('The mean of the height(e group) is:', height_mean, 'The median of the height(e group) is:', height_median, 'The sd of the height(e group) is:', height_mean)

weight_mean = df_e['Weight (kg)'].mean()
weight_median = df_e['Weight (kg)'].median()
weight_sd = df_e['Weight (kg)'].std()
print('The mean of the weight(e group) is:', weight_mean, 'The median of the weight(e group) is:', weight_mean, 'The sd of the weight(e group) is:', weight_mean)

BMI_mean = df_e['BMI (kg/m^2)'].mean()
BMI_median = df_e['BMI (kg/m^2)'].median()
BMI_sd = df_e['BMI (kg/m^2)'].std()
print('The mean of the BMI(e group) is:', BMI_mean, 'The median of the BMI(e group) is:', BMI_median, 'The sd of the BMI(e group) is:', BMI_sd)
# Out:
# The mean of the age(e group) is: 47.91647855530474 The median of the age(e group) is: 46.0 The sd of the age(e group) is: 17.384128983430493
# The mean of the height(e group) is: 182.24830699774267 The median of the height(e group) is: 183.0 The sd of the height(e group) is: 182.24830699774267
# The mean of the weight(e group) is: 80.50338600451467 The median of the weight(e group) is: 80.50338600451467 The sd of the weight(e group) is: 80.50338600451467
# The mean of the BMI(e group) is: 25.05771515543322 The median of the BMI(e group) is: 23.80869017191275 The sd of the BMI(e group) is: 9.298824994910483

# %% [markdown]
# What statistical test should be employed to analyze the effectiveness of the new heart failure medication formulations developed by two pharmaceutical companies, sacubitril and enalapril, with respect to their claims of reducing NT-proBNP levels? The claims state that sacubitril reduces NT-proBNP levels by an average of 3000 within 4 weeks and 2000 within 8 weeks, while enalapril reduces NT-proBNP levels by an average of 2500 within 4 weeks and 1500 within 8 weeks. A clinical trial was conducted using samples from both companies, and the objective is to determine which formulation is more effective.
#
# Clearly state your hypotheses for the combinations of analyses and do the significance test accordingly:
#
# 1. For the sacubitril group, is there a significant difference between pre-treatment and Week 4 NT-proBNP levels? (2 Points)
#
# 2. For the sacubitril group, is there a significant difference between pre-treatment and Week 8 NT-proBNP levels? (2 Points)
#
# 3. For the enalapril group, is there a significant difference between pre-treatment and Week 4 NT-proBNP levels? (2 Points)
#
# 4. For the enalapril group, is there a significant difference between pre-treatment and Week 8 NT-proBNP levels? (2 Points)
#
# 5. Is there a significant difference in NT-proBNP levels at Week 4 between the two groups (sacubitril and enalapril)? (2 Points)
#
# 6. Is there a significant difference in NT-proBNP levels at Week 8 between the two groups (sacubitril and enalapril)? (2 Points)
#
# 7. Among participants aged 60 or older, is there a significant difference in NT-proBNP levels at Week 4 between the two groups (sacubitril and enalapril)? (2 Points)
#
# 8. Among participants aged 60 or older, is there a significant difference in NT-proBNP levels at Week 8 between the two groups (sacubitril and enalapril)? (2 Points)

# %% [markdown]
# **Q1: For the sacubitril group, is there a significant difference between pre-treatment and Week 4 NT-proBNP levels? (2 Points)**

# %% [markdown]
# 𝐻0: μp = μ4
#
# (There is no significant difference between pre-treatment (p) and Week 4 NT-proBNP (4)levels on its mean levels, μ)
#
# 𝐻1: μp ≠ μ4
#
# (There is a significant difference between pre-treatment and Week 4 NT-proBNP levels on its mean levels, μ)

# %%
week_4
# Out:
#      Week 4 NT-proBNP (pg/mL)                 Group Timepoint
# 334                  4530.107             Enalapril    Week 4
# 958                  3766.125  Sacubitril-valsartan    Week 4
# 228                  4176.815             Enalapril    Week 4
# 120                  4090.336             Enalapril    Week 4
# 795                  3177.617  Sacubitril-valsartan    Week 4
# ..                        ...                   ...       ...
# 72                   4528.170             Enalapril    Week 4
# 489                  4599.796             Enalapril    Week 4
# 481                  4397.426             Enalapril    Week 4
# 105                  4585.846             Enalapril    Week 4
# 41                   4374.684             Enalapril    Week 4
#
# [888 rows x 3 columns]

# %%
#Since its two sample, first see if it's normally distributed or not, and we do Kolmogorov-Smirnov Test (KS test)
import scipy.stats as stats
# Extract the columns to test first (for group p)
pre_treatment_values = pre_treatment.loc[pre_treatment['Group']=='Sacubitril-valsartan','Pre-treatment NT-proBNP (pg/mL)']
week_4_values = week_4.loc[week_4['Group']=='Sacubitril-valsartan','Week 4 NT-proBNP (pg/mL)']

# %%
#See if they are normally distributed via graph first
sns.histplot(pre_treatment_values, kde=True, color='blue', label='Pre-treatment')
sns.histplot(week_4_values, kde=True, color='orange', label='Week 4')
plt.legend()
plt.show()

# %%
#The graph shows a no, but since we have not learned the test on not normally distributed data yet, I will still use paired t-test here (same as the rest of questions)
from scipy.stats import ttest_rel

# Perform paired-sample t-test
t_statistic, p_value = ttest_rel(pre_treatment_values, week_4_values)

# Check if the p-value is less than the significance level which is set at 0.05
alpha = 0.05
if p_value < alpha:
    print("Reject the null hypothesis. There is a significant difference between pre-treatment and Week 4 NT-proBNP levels on its mean levels, μ.")
else:
    print("Fail to reject the null hypothesis. There is no significant difference between pre-treatment and Week 4 NT-proBNP levels on its mean levels, μ.")
# Out:
# Reject the null hypothesis. There is a significant difference between pre-treatment and Week 4 NT-proBNP levels on its mean levels, μ.

# %% [markdown]
# **Q2: For the sacubitril group, is there a significant difference between pre-treatment and Week 8 NT-proBNP levels? (2 Points)**

# %% [markdown]
# 𝐻0: μp = μ8
#
# (There is no significant difference between pre-treatment (p) and Week 8 NT-proBNP (8)levels on its mean levels, μ)
#
# 𝐻1: μp ≠ μ8
#
# (There is a significant difference between pre-treatment and Week 8 NT-proBNP levels on its mean levels, μ)

# %%
#Same as above, instead we need to create a new variable for week 8
week_8_values = week_8.loc[week_8['Group']=='Sacubitril-valsartan','Week 8 NT-proBNP (pg/mL)']

# %%
sns.histplot(pre_treatment_values, kde=True, color='blue', label='Pre-treatment')
sns.histplot(week_8_values, kde=True, color='orange', label='Week 8')
plt.legend()
plt.show()

# %%
#The graph shows a no, but since we have not learned the test on not normally distributed data yet, I will still use paired t-test here (same as the rest of questions)
from scipy.stats import ttest_rel

# Perform paired-sample t-test
t_statistic, p_value = ttest_rel(pre_treatment_values, week_8_values)

# Check if the p-value is less than the significance level which is set at 0.05
alpha = 0.05
if p_value < alpha:
    print("Reject the null hypothesis. There is a significant difference between pre-treatment and Week 8 NT-proBNP levels on its mean levels, μ.")
else:
    print("Fail to reject the null hypothesis. There is no significant difference between pre-treatment and Week 8 NT-proBNP levels on its mean levels, μ.")
# Out:
# Reject the null hypothesis. There is a significant difference between pre-treatment and Week 8 NT-proBNP levels on its mean levels, μ.

# %% [markdown]
# **Q3: For the enalapril group, is there a significant difference between pre-treatment and Week 4 NT-proBNP levels? (2 Points)**

# %% [markdown]
# <font color='red'>This time is for group e
#
# ---
#
#
# 𝐻0: μp = μ4
#
# (There is no significant difference between pre-treatment (p) and Week 4 NT-proBNP (4)levels on its mean levels, μ)
#
# 𝐻1: μp ≠ μ4
#
# (There is a significant difference between pre-treatment and Week 4 NT-proBNP levels on its mean levels, μ)

# %%
#Since its two sample, first see if it's normally distributed or not, and we do Kolmogorov-Smirnov Test (KS test)
import scipy.stats as stats
# Extract the columns to test first (for group p)
pre_treatment_values_E = pre_treatment.loc[pre_treatment['Group']=='Enalapril','Pre-treatment NT-proBNP (pg/mL)']
week_4_values_E = week_4.loc[week_4['Group']=='Enalapril','Week 4 NT-proBNP (pg/mL)']

# %%
#See if they are normally distributed via graph first
sns.histplot(pre_treatment_values_E, kde=True, color='blue', label='Pre-treatment')
sns.histplot(week_4_values_E, kde=True, color='orange', label='Week 4')
plt.legend()
plt.show()

# %%
#Again, we don't see a normal distribution, but paired t-test here it is:
# Perform paired-sample t-test for group e
t_statistic, p_value = ttest_rel(pre_treatment_values_E, week_4_values_E)

# Check if the p-value is less than the significance level which is set at 0.05
alpha = 0.05
if p_value < alpha:
    print("Reject the null hypothesis. There is a significant difference between pre-treatment and Week 4 NT-proBNP levels on its mean levels, μ.")
else:
    print("Fail to reject the null hypothesis. There is no significant difference between pre-treatment and Week 4 NT-proBNP levels on its mean levels, μ.")
# Out:
# Reject the null hypothesis. There is a significant difference between pre-treatment and Week 4 NT-proBNP levels on its mean levels, μ.

# %% [markdown]
# **Q4: For the enalapril group, is there a significant difference between pre-treatment and Week 8 NT-proBNP levels?**

# %% [markdown]
# <font color='red'>This time is for group e
#
# ---
#
#
#
# 𝐻0: μp = μ8
#
# (There is no significant difference between pre-treatment (p) and Week 8 NT-proBNP (8)levels on its mean levels, μ)
#
# 𝐻1: μp ≠ μ8
#
# (There is a significant difference between pre-treatment and Week 8 NT-proBNP levels on its mean levels, μ)

# %%
#Since its two sample, first see if it's normally distributed or not, and we do Kolmogorov-Smirnov Test (KS test)
import scipy.stats as stats
# Extract the columns to test first (for group p)
pre_treatment_values_E = pre_treatment.loc[pre_treatment['Group']=='Enalapril','Pre-treatment NT-proBNP (pg/mL)']
week_8_values_E = week_8.loc[week_8['Group']=='Enalapril','Week 8 NT-proBNP (pg/mL)']

# %%
#See if they are normally distributed via graph first
sns.histplot(pre_treatment_values_E, kde=True, color='blue', label='Pre-treatment')
sns.histplot(week_8_values_E, kde=True, color='orange', label='Week 8')
plt.legend()
plt.show()

# %%
#Again, we don't see a normal distribution, but paired t-test here it is:
# Perform paired-sample t-test for group e
t_statistic, p_value = ttest_rel(pre_treatment_values_E, week_8_values_E)

# Check if the p-value is less than the significance level which is set at 0.05
alpha = 0.05
if p_value < alpha:
    print("Reject the null hypothesis. There is a significant difference between pre-treatment and Week 8 NT-proBNP levels on its mean levels, μ.")
else:
    print("Fail to reject the null hypothesis. There is no significant difference between pre-treatment and Week 8 NT-proBNP levels on its mean levels, μ.")
# Out:
# Reject the null hypothesis. There is a significant difference between pre-treatment and Week 8 NT-proBNP levels on its mean levels, μ.

# %% [markdown]
# **Q5: Is there a significant difference in NT-proBNP levels at Week 4 between the two groups (sacubitril and enalapril)?**

# %% [markdown]
# 𝐻0:μ（e）=μ（sv）
#
# There is no significant difference between the median of Week 4 NT-proBNP group where patients were given Enalapril and Sacubitril-valsartan.
#
# 𝐻1:μ（e）≠μ（sv）
#
# There is a significant difference between the median of Week 4 NT-proBNP group where patients were given Enalapril and Sacubitril-valsartan.

# %%
#We do one-sample Kolmogorov–Smirnov test (using a normal distribution) (n >= 50) for each group to see their distribution first:
stats.kstest(week_4_values, 'norm')
stats.kstest(week_4_values_E, 'norm')
# Out:
# KstestResult(statistic=1.0, pvalue=0.0, statistic_location=3907.227, statistic_sign=-1)

# %% [markdown]
# *The very small p-value provides evidence to reject the null hypothesis of no difference in distribution.*

# %% [markdown]
# <font color=blue>Also, This question suggests comparing two independent groups (sacubitril group vs. enalapril group), so I would use an independent t-test. But need to check its variance first to decide.

# %%
#Use levene test to see its variance first
stats.levene(week_4_values, week_4_values_E)
# Out:
# LeveneResult(statistic=36.33159208921559, pvalue=2.4398294322184967e-09)

# %% [markdown]
# Low p value from levene test means that Variances are not equal between the samples' populations. So we will do Welch's T-test ultimately.

# %% [markdown]
# From the claims we find that in week 4, s group is in average at 3000 which is higher than e group at 2500. Thus the hypothesis becomes:
#
# 𝐻0:μe=𝑢sv
#
# 𝐻1:μe<𝑢sv

# %%
stats.ttest_ind(week_4_values.dropna(), week_4_values_E.dropna(), alternative = 'less', equal_var=False)
# Out:
# TtestResult(statistic=-45.84265984538681, pvalue=1.0766881823821868e-228, df=819.5443801970529)

# %% [markdown]
# From the result we see that pvalue is way less than 0.05 and thus the H0 is rejected and thus H1 is embraced that there is a siginificant difference b/w the two groups at week 4 in that group e's mean is less than group sv's mean in terms of NT-proBNP (pg/ml).

# %% [markdown]
# **Q6: Is there a significant difference in NT-proBNP levels at Week 8 between the two groups (sacubitril and enalapril)?**

# %%
#We do one-sample Kolmogorov–Smirnov test (using a normal distribution) (n >= 50) for each group to see their distribution first:
stats.kstest(week_8_values, 'norm')
stats.kstest(week_8_values_E, 'norm')
# Out:
# KstestResult(statistic=1.0, pvalue=0.0, statistic_location=2918.699, statistic_sign=-1)

# %% [markdown]
# Seems like two are not shaped the same again (assume normally distrubuted, otherwise haven't learned the abnormal distribution test)

# %%
#Use levene test to see its variance first
stats.levene(week_8_values, week_8_values_E)
# Out:
# LeveneResult(statistic=141.59847786845978, pvalue=2.1420240030985757e-30)

# %% [markdown]
# Low p value from levene test means that Variances are not equal between the samples' populations. So we will do Welch's T-test ultimately.

# %% [markdown]
# From the claims we find that in <font color=red>week 8, <font color = black>s group is in average at 2000 which is higher than e group at 1500. Thus the hypothesis becomes:
#
# 𝐻0:μe=𝑢sv
#
# 𝐻1:μe<𝑢sv

# %%
stats.ttest_ind(week_8_values.dropna(), week_8_values_E.dropna(), alternative = 'less', equal_var=False)
# Out:
# TtestResult(statistic=-85.24649223433032, pvalue=0.0, df=675.1189223609658)

# %% [markdown]
# From the result we see that pvalue is way less than 0.05 and thus the H0 is rejected and thus H1 is embraced that there is a siginificant difference b/w the two groups at <font color=red>week 8 <font color=black>in that group e's mean is less than group sv's mean in terms of NT-proBNP (pg/ml).

# %% [markdown]
# **Q7: Among participants aged 60 or older, is there a significant difference in NT-proBNP levels at Week 4 between the two groups (sacubitril and enalapril)?**

# %%
week_4
# Out:
#      Week 4 NT-proBNP (pg/mL)                 Group Timepoint
# 334                  4530.107             Enalapril    Week 4
# 958                  3766.125  Sacubitril-valsartan    Week 4
# 228                  4176.815             Enalapril    Week 4
# 120                  4090.336             Enalapril    Week 4
# 795                  3177.617  Sacubitril-valsartan    Week 4
# ..                        ...                   ...       ...
# 72                   4528.170             Enalapril    Week 4
# 489                  4599.796             Enalapril    Week 4
# 481                  4397.426             Enalapril    Week 4
# 105                  4585.846             Enalapril    Week 4
# 41                   4374.684             Enalapril    Week 4
#
# [888 rows x 3 columns]

# %% [markdown]
# Now lets investigate the aged group over 60. First name the new variables.

# %%
week_4_60S= week_4.loc[(new_df['Age']>=60) & (new_df['Group']=='Sacubitril-valsartan'),'Week 4 NT-proBNP (pg/mL)']
week_4_60S
# Out:
# 948    2962.996
# 829    4419.131
# 724    2787.073
# 884    3091.993
# 559    3475.782
#          ...
# 574    4175.210
# 985    3671.359
# 770    3185.233
# 863    3394.942
# 550    2891.603
# Name: Week 4 NT-proBNP (pg/mL), Length: 124, dtype: float64

# %%
#seems we got 124 candidates fit the criteria, now the same for group e.
week_4_60E= week_4.loc[(new_df['Age']>=60) & (new_df['Group']=='Enalapril'),'Week 4 NT-proBNP (pg/mL)']
week_4_60E
# Out:
# 241    4679.187
# 284    4411.067
# 214    4890.564
# 31     3930.906
# 233    4750.694
#          ...
# 72     4528.170
# 489    4599.796
# 481    4397.426
# 105    4585.846
# 41     4374.684
# Name: Week 4 NT-proBNP (pg/mL), Length: 128, dtype: float64

# %% [markdown]
# Same procedure as in Q5 and 6

# %%
#We do one-sample Kolmogorov–Smirnov test (using a normal distribution) (n >= 50) for each group to see their distribution first:
stats.kstest(week_4_60E, 'norm')
stats.kstest(week_4_60S, 'norm')
# Out:
# KstestResult(statistic=1.0, pvalue=0.0, statistic_location=2787.073, statistic_sign=-1)

# %% [markdown]
# *The very small p-value provides evidence to reject the null hypothesis of no difference in distribution.*

# %% [markdown]
# <font color=blue>Also, This question suggests comparing two independent groups (sacubitril group vs. enalapril group), so I would use an independent t-test. But need to check its variance first to decide.

# %%
#Use levene test to see its variance first
stats.levene(week_4_60S, week_4_60E)
# Out:
# LeveneResult(statistic=6.253594473005219, pvalue=0.013035067282235854)

# %% [markdown]
# Low p value below 0.05 from levene test means that Variances are not equal between the samples' populations. So we will do Welch's T-test ultimately.

# %% [markdown]
# This time since we don't have the preclaims, we will do two-sided test instead. Thus the hypothesis becomes:
#
# 𝐻0:μe=𝑢sv
#
# （ There is no significant difference between the median of Week 4 NT-proBNP group where patients were given Enalapril and Sacubitril-valsartan)
#
# 𝐻1:μe≠𝑢sv
#
# (There is a significant difference between the median of Week 4 NT-proBNP group where patients were given Enalapril and Sacubitril-valsartan)

# %%
stats.ttest_ind(week_4_60S.dropna(), week_4_60E.dropna(), alternative = 'two-sided', equal_var=False)
# Out:
# TtestResult(statistic=-25.182310394016216, pvalue=3.337183055431325e-69, df=239.1302346525214)

# %% [markdown]
# From the result we see that pvalue is way less than 0.05 and thus the H0 is rejected and thus H1 is embraced that there is a significant difference between the median of Week 4 NT-proBNP group where patients were given Enalapril and Sacubitril-valsartan aged over 60.

# %% [markdown]
# **Q8: Among participants aged 60 or older, is there a significant difference in NT-proBNP levels at Week 8 between the two groups (sacubitril and enalapril)?**

# %%
week_8_60S= week_8.loc[(new_df['Age']>=60) & (new_df['Group']=='Sacubitril-valsartan'),'Week 8 NT-proBNP (pg/mL)']
week_8_60E= week_8.loc[(new_df['Age']>=60) & (new_df['Group']=='Enalapril'),'Week 8 NT-proBNP (pg/mL)']

# %% [markdown]
# Same procedure as in Q7 above...

# %%
#We do one-sample Kolmogorov–Smirnov test (using a normal distribution) (n >= 50) for each group to see their distribution first:
stats.kstest(week_8_60E, 'norm')
stats.kstest(week_8_60S, 'norm')
# Out:
# KstestResult(statistic=1.0, pvalue=0.0, statistic_location=1485.51, statistic_sign=-1)

# %% [markdown]
# *The very small p-value provides evidence to reject the null hypothesis of no difference in distribution.*

# %% [markdown]
# <font color=blue>Also, This question suggests comparing two independent groups (sacubitril group vs. enalapril group), so I would use an independent t-test. But need to check its variance first to decide.

# %%
#Use levene test to see its variance first
stats.levene(week_8_60S, week_8_60E)
# Out:
# LeveneResult(statistic=31.321014362773425, pvalue=5.736333781005819e-08)

# %% [markdown]
# Low p value below 0.05 from levene test means that Variances are not equal between the samples' populations. So we will do Welch's T-test ultimately.

# %% [markdown]
# This time since we don't have the preclaims, we will do two-sided test instead. Thus the hypothesis becomes:
#
# 𝐻0:μe=𝑢sv
#
# （ There is no significant difference between the median of **Week 8** NT-proBNP group where patients were given Enalapril and Sacubitril-valsartan)
#
# 𝐻1:μe≠𝑢sv
#
# (There is a significant difference between the median of **Week 8** NT-proBNP group where patients were given Enalapril and Sacubitril-valsartan)

# %%
stats.ttest_ind(week_8_60S.dropna(), week_8_60E.dropna(), alternative = 'two-sided', equal_var=False)
# Out:
# TtestResult(statistic=-47.228994957692386, pvalue=2.0160063600606074e-110, df=199.99095428371749)

# %% [markdown]
# From the result we see that pvalue is way less than 0.05 and thus the H0 is rejected and thus H1 is embraced that there is a significant difference between the median of **Week 8** NT-proBNP group where patients were given Enalapril and Sacubitril-valsartan aged over 60.

# %% [markdown]
# **Additional Q: Is there a statistically significant difference between the pre-treatment NT-proBNP and week 4 NT-proBNP, and between baseline and week 8 NT-proBNP in sacubitril/valsartan and enalapril groups? (2 points)**

# %% [markdown]
# First we need to create a new df calculating the difference and stored as df_dif.

# %%
new_df.head()
# Out:
#       Age     Sex              Race               Ethnicity  Height (cm)  \
# 334  18.0  Female         Caucasian      Hispanic or Latino        161.0
# 958  18.0    Male         Caucasian  Not Hispanic or Latino        211.0
# 228  18.0  Female  Pacific Islander      Hispanic or Latino        152.0
# 120  18.0  Female           Unknown  Not Hispanic or Latino        199.0
# 795  18.0  Female         Caucasian  Not Hispanic or Latino        197.0
#
#      Weight (kg) Smoking history  Pre-treatment NT-proBNP (pg/mL)  \
# 334        111.0           never                         6064.400
# 958         62.0          former                         7065.900
# 228        118.0           never                         5591.452
# 120         91.0         current                         5475.684
# 795         91.0           never                         5961.758
#
#      Week 4 NT-proBNP (pg/mL)  Week 8 NT-proBNP (pg/mL)  ...  \
# 334                  4530.107                  3383.990  ...
# ...

# %%
#define the df_dif.
# Calculate the differences for week 4
new_df['Week4_NTproBNP_diff'] = abs(new_df['Week 4 NT-proBNP (pg/mL)'] - new_df['Pre-treatment NT-proBNP (pg/mL)'])

# Calculate the differences for week 8
new_df['Week8_NTproBNP_diff'] = abs(new_df['Week 8 NT-proBNP (pg/mL)'] - new_df['Pre-treatment NT-proBNP (pg/mL)'])

new_df.head()
# Out:
#       Age     Sex              Race               Ethnicity  Height (cm)  \
# 334  18.0  Female         Caucasian      Hispanic or Latino        161.0
# 958  18.0    Male         Caucasian  Not Hispanic or Latino        211.0
# 228  18.0  Female  Pacific Islander      Hispanic or Latino        152.0
# 120  18.0  Female           Unknown  Not Hispanic or Latino        199.0
# 795  18.0  Female         Caucasian  Not Hispanic or Latino        197.0
#
#      Weight (kg) Smoking history  Pre-treatment NT-proBNP (pg/mL)  \
# 334        111.0           never                         6064.400
# 958         62.0          former                         7065.900
# 228        118.0           never                         5591.452
# 120         91.0         current                         5475.684
# 795         91.0           never                         5961.758
#
#      Week 4 NT-proBNP (pg/mL)  Week 8 NT-proBNP (pg/mL)  ...  \
# 334                  4530.107                  3383.990  ...
# ...

# %%
#Extract the two groups in terms of their diff for week 4 first:
diff_4E= new_df.loc[(new_df['Group']=='Sacubitril-valsartan'),['Week4_NTproBNP_diff']]
diff_4S= new_df.loc[(new_df['Group']=='Enalapril'),['Week4_NTproBNP_diff']]

# %%
#Same for Week 8:
diff_8E= new_df.loc[(new_df['Group']=='Sacubitril-valsartan'),['Week8_NTproBNP_diff']]
diff_8S= new_df.loc[(new_df['Group']=='Enalapril'),['Week8_NTproBNP_diff']]

# %%
'''This time they are paired from the same sample, so we do sampled t-test assuming they are normally distributed, but quick check first as in Q1 and 2.'''
# Out:
# 'This time they are paired from the same sample, so we do sampled t-test assuming they are normally distributed, but quick check first as in Q1 and 2.'

# %%
#See if they are normally distributed via graph first, for Group E
sns.histplot(diff_4E, kde=True, color='blue', label='Week 4')
sns.histplot(diff_8E, kde=True, color='red', label='Week 8')
plt.legend()
plt.show()

# %% [markdown]
# Hypothesis 1 on Enalapril:
#
# 𝐻0:μe=μsv
#
# (There is no significant difference between the absolute mean of (pre-treatment NT-proBNP - week4 NT-proBNP)(μe) and the mean of (pre-treatment NT-proBNP - week8 NT-proBNP(μs) after treated with Enalapril.))
#
# 𝐻1:μe≠μsv
#
# (There is a significant difference between.)

# %%
#Somehow the color didnt work, but anyway we don't see a normal distribution, but paired t-test here it is:
# Perform paired-sample t-test for Week 4 b/w two groups
t_statistic, p_value = ttest_rel(diff_4E, diff_8E)

# Check if the p-value is less than the significance level which is set at 0.05
alpha = 0.05
if p_value < alpha:
    print("Reject the null hypothesis. There is a significant difference between the absolute mean of two groups with baseline for Group E")
else:
    print("Fail to reject the null hypothesis. There is no significant difference between the absolute mean of two groups with baseline for Group E")
# Out:
# Reject the null hypothesis. There is a significant difference between the absolute mean of two groups with baseline for Group E

# %% [markdown]
# Hypothesis 2 on Sacubitril-valsartan:
#
# 𝐻0:μe=μsv
#
# (There is no significant difference between the absolute mean of (pre-treatment NT-proBNP - week4 NT-proBNP)(μe) and the mean of (pre-treatment NT-proBNP - week8 NT-proBNP(μs) after treated with Sacubitril-valsartan.))
#
# 𝐻1:μe≠μsv
#
# (There is a significant difference between.)

# %%
#Somehow the color didnt work, but anyway we don't see a normal distribution, but paired t-test here it is:
# Perform paired-sample t-test for Week 4 b/w two groups
t_statistic, p_value = ttest_rel(diff_4S, diff_8S)

# Check if the p-value is less than the significance level which is set at 0.05
alpha = 0.05
if p_value < alpha:
    print("Reject the null hypothesis. There is a significant difference between the absolute mean of two groups with baseline for Group S")
else:
    print("Fail to reject the null hypothesis. There is no significant difference between the absolute mean of two groups with baseline for Group S")
# Out:
# Reject the null hypothesis. There is a significant difference between the absolute mean of two groups with baseline for Group S

# %% [markdown]
# ## **Final Step: Re-Organize all the files and graphs and git push to the GitHub**

# %% [markdown]
# ###**Step 1: Data Structure Build-up**

# %%
df.to_csv('StartingDF.csv')

# %%
new_df.head()
# Out:
#       Age     Sex              Race               Ethnicity  Height (cm)  \
# 334  18.0  Female         Caucasian      Hispanic or Latino        161.0
# 958  18.0    Male         Caucasian  Not Hispanic or Latino        211.0
# 228  18.0  Female  Pacific Islander      Hispanic or Latino        152.0
# 120  18.0  Female           Unknown  Not Hispanic or Latino        199.0
# 795  18.0  Female         Caucasian  Not Hispanic or Latino        197.0
#
#      Weight (kg) Smoking history  Pre-treatment NT-proBNP (pg/mL)  \
# 334        111.0           never                         6064.400
# 958         62.0          former                         7065.900
# 228        118.0           never                         5591.452
# 120         91.0         current                         5475.684
# 795         91.0           never                         5961.758
#
#      Week 4 NT-proBNP (pg/mL)  Week 8 NT-proBNP (pg/mL)  ...  \
# 334                  4530.107                  3383.990  ...
# ...

# %%
new_df.to_csv("FinalDF.csv")

# %%
#First examine all the columns to choose the one to be graphed
sorted(new_df)
# Out:
# ['Age',
#  'BMI (kg/m^2)',
#  'Chronic renal insufficiency',
#  'Death',
#  'Ethnicity',
#  'Group',
#  'Height (cm)',
#  'Hyperkalemia',
#  'Left ventricular ejection fraction (%)',
#  'Pre-treatment BNP (pg/mL)',
#  'Pre-treatment NT-proBNP (pg/mL)',
#  'Prior use of ACEi/ARB',
#  'Race',
#  'Sex',
#  'Smoking history',
#  'Symptomatic hypotension',
#  'Week 4 NT-proBNP (pg/mL)',
#  'Week 8 NT-proBNP (pg/mL)',
#  'Week4_NTproBNP_diff',
#  'Week8_NTproBNP_diff',
#  'Weight (kg)']

# %% [markdown]
# ###Generate a summary graph as well, I choose LVEF%:

# %%
# import LVEF data for filtered df
LVEF = new_df['Left ventricular ejection fraction (%)']
sns.set(style="whitegrid")
# Creating the histogram of BMI to see its frequency
sns.histplot(LVEF)
# Converting the description to a string
description = LVEF.describe().to_string()
# Adding the description as figure text to show in the figure
plt.figtext(1.0, 0.3, description)
plt.show()
plt.savefig('SummaryOfLVEF%.pdf', bbox_inches='tight')

# %% [markdown]
# ###**Publication on GitHub**

# %% [markdown]
#  **Create the folder structures that contains all the required tables,readmes and figures first.**

# %%
rm -r sample_data/

# %%
# %%bash
# cat > .gitignore
# .*
# .gitignore
#
# git config --global user.email "zoul@usc.edu"
# git config --global user.name "Loe-zou"

# %%
# %%bash
# git init
# Out:
# Initialized empty Git repository in /content/.git/
# hint: Using 'master' as the name for the initial branch. This default branch name
# hint: is subject to change. To configure the initial branch name to use in all
# hint: of your new repositories, which will suppress this warning, call:
# hint:
# hint: 	git config --global init.defaultBranch <name>
# hint:
# hint: Names commonly chosen instead of 'master' are 'main', 'trunk' and
# hint: 'development'. The just-created branch can be renamed via this command:
# hint:
# hint: 	git branch -m <name>

# %%
# %%bash
# mkdir startingData results figures code

# %%
# %%bash
# touch README.md
# echo "This is the GitHub upload for CXPT501 Final project for Linghao Zou (ID-6094). Please find the 'startingData' 'results' 'figures' and 'code' in respective folder on this repository, and feel free to contact zoul@usc.edu for any concerns. Thanks! " > README.md
# cat README.md
# Out:
# This is the GitHub upload for CXPT501 Final project for Linghao Zou (ID-6094). Please find the 'startingData' 'results' 'figures' and 'code' in respective folder on this repository, and feel free to contact zoul@usc.edu for any concerns. Thanks!

# %%
# %%bash
# mv StartingDF.csv /content/startingData/

# %%
# %%bash
# cd /content/startingData/
# echo "This is the original data frame given - aka the raw data" > READNE.md

# %%
# %%bash
# mv FinalDF.csv /content/results/

# %%
# %%bash
# cd results/
# echo "This is the final dataframe after steps of wrangling, cleaning, computing and re-organzation." > README.md

# %%
# %%bash
# pwd
# Out:
# /content

# %%
# %%bash
# mv NT-proBMP_over_time.pdf SummaryOfLVEF%.pdf bar_plot_weeks.pdf heatmap_ethnity.pdf heatmap_race.pdf violin.pdf /content/figures/

# %%
# %%bash
# cd figures/
# echo "# This folder contains 6 figures for visualizing different parameters from the cleaned data" > README.md
# echo "## Please find the descriptions and explanations on all the graphs under code section" >> README.md
# echo "##Also noted that the one contains both summary statistics and distributions is called 'SummaryOfLVEF%.pdf'">> README.md

# %%
# %%bash
# cd code/
# echo "##This is the folder including the entire code written for analyzing the data frame." > README.md
# echo "Please check into it carefully for all the data managing and statistical analysis part. Also the google colab link has been included in the end" >> README.md

# %%
# %%bash
# mv CXPT501_Lab09_AdditionalStatisticsAndReview.ipynb code/

# %% [markdown]
# **Next, git add all the changes to github for check.**

# %%
# %%bash
# git add -A

# %%
# %%bash
# cat > .gitignore
# .*
# .gitignore
#
# git config --global user.email "zoul@usc.edu"
# git config --global user.name "Loe-zou"

# %%
# %%bash
# git config --global user.email "zoul@usc.edu"
# git config --global user.name "Loe-zou"
# git commit -m 'Lab09'
# Out:
# [master (root-commit) ea20a4b] Lab09
#  13 files changed, 18698 insertions(+)
#  create mode 100644 README.md
#  create mode 100644 code/CXPT501_Lab09_AdditionalStatisticsAndReview.ipynb
#  create mode 100644 code/README.md
#  create mode 100644 figures/Figure1.pdf
#  create mode 100644 figures/Figure2.pdf
#  create mode 100644 figures/Figure3.pdf
#  create mode 100644 figures/README.md
#  create mode 100644 results/ProbabilityMatrix_pseudo.csv
#  create mode 100644 results/README.md
#  create mode 100644 results/confusionMatrixMetrics_pseudo.csv
#  create mode 100644 startingData/DIG.csv
#  create mode 100644 startingData/DIG_Raw.csv
#  create mode 100644 startingData/READNE.md

# %% [markdown]
# Had to run this step again somehow to verify the github config...

# %%
# %%bash
# rm ~/.ssh/id_ed25519
# ssh-keygen -t ed25519 -C 'zoul@usc.edu' -f ~/.ssh/id_ed25519 -P ''
# cat > ~/.ssh/config
# Host *
#   AddKeysToAgent yes
#   IdentityFile ~/.ssh/id_ed25519
# Out:
# Generating public/private ed25519 key pair.
# Your identification has been saved in /root/.ssh/id_ed25519
# Your public key has been saved in /root/.ssh/id_ed25519.pub
# The key fingerprint is:
# SHA256:R6c6vfsMB54XRjhjafMcKCtyE/oxVHH4VUNEOBl3+Gs zoul@usc.edu
# The key's randomart image is:
# +--[ED25519 256]--+
# |        oo. .OB..|
# |       ... +=..o |
# |      o ..@.+. . |
# |     o . *.X .  .|
# |    o * S + =   .|
# |     + = = + . E |
# |      . o = o .  |
# |         . *     |
# |          ooo    |
# +----[SHA256]-----+

# %%
# %%bash
# cat ~/.ssh/id_ed25519
# Out:
# -----BEGIN OPENSSH PRIVATE KEY-----
# b3BlbnNzaC1rZXktdjEAAAAABG5vbmUAAAAEbm9uZQAAAAAAAAABAAAAMwAAAAtzc2gtZW
# QyNTUxOQAAACBlG0kFgAhENmvwmvlJCgINHMj1VEK+wA7u4xqHNCRd+QAAAJA6Mz+YOjM/
# mAAAAAtzc2gtZWQyNTUxOQAAACBlG0kFgAhENmvwmvlJCgINHMj1VEK+wA7u4xqHNCRd+Q
# AAAEAvTjQzoOpriEMn3+0vyGJiOYMPqSsxl28wOWDCFZXvz2UbSQWACEQ2a/Ca+UkKAg0c
# yPVUQr7ADu7jGoc0JF35AAAADHpvdWxAdXNjLmVkdQE=
# -----END OPENSSH PRIVATE KEY-----

# %%
# %%bash
# eval "$(ssh-agent -s)"
# ssh-add ~/.ssh/id_ed25519
# Out:
# Agent pid 78343
# Identity added: /root/.ssh/id_ed25519 (zoul@usc.edu)

# %%
# %%bash
# cat ~/.ssh/id_ed25519.pub
# Out:
# ssh-ed25519 AAAAC3NzaC1lZDI1NTE5AAAAIGUbSQWACEQ2a/Ca+UkKAg0cyPVUQr7ADu7jGoc0JF35 zoul@usc.edu

# %%
# %%bash
# cat ~/.ssh/id_ed25519
# Out:
# -----BEGIN OPENSSH PRIVATE KEY-----
# b3BlbnNzaC1rZXktdjEAAAAABG5vbmUAAAAEbm9uZQAAAAAAAAABAAAAMwAAAAtzc2gtZW
# QyNTUxOQAAACBlG0kFgAhENmvwmvlJCgINHMj1VEK+wA7u4xqHNCRd+QAAAJA6Mz+YOjM/
# mAAAAAtzc2gtZWQyNTUxOQAAACBlG0kFgAhENmvwmvlJCgINHMj1VEK+wA7u4xqHNCRd+Q
# AAAEAvTjQzoOpriEMn3+0vyGJiOYMPqSsxl28wOWDCFZXvz2UbSQWACEQ2a/Ca+UkKAg0c
# yPVUQr7ADu7jGoc0JF35AAAADHpvdWxAdXNjLmVkdQE=
# -----END OPENSSH PRIVATE KEY-----

# %%
# %%bash
# ssh -o "StrictHostKeyChecking no" -T git@github.com | exit 0
# Out:
# Hi Loe-zou! You've successfully authenticated, but GitHub does not provide shell access.

# %%
# %%bash
# git remote set-url origin git@github.com:Loe-zou/CXPT501_LAB_09.git
# git branch -M main
# git push -u origin main
# Out:
# Branch 'main' set up to track remote branch 'main' from 'origin'.
# To github.com:Loe-zou/CXPT501_LAB_09.git
#  * [new branch]      main -> main

# %% [markdown]
# *Tips: To obtain the `CXPT501_Lab08_Public.ipynb` file, select `File -> Download -> Download .ipynb`.*

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Then, you can manually upload this file to your notebook by clicking on the `Upload to session storage` button boxed in red.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### **Step 2: GitHub Link**

# %% [markdown]
# Here is the link for the colab:[Google Colab Notebook](https://colab.research.google.com/drive/1yYdu7TlDSvc6TQGAvqIdYj3TYcljrZ6d#scrollTo=NsZBIOC1QWRN)
